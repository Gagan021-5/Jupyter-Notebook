# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %%
df = pd.read_csv('weight-height.csv')

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df.shape
# Out:
# (10000, 3)

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
import seaborn as sb

# %%
sb.histplot(df['Height'])
# Out:
# <Axes: xlabel='Height', ylabel='Count'>

# %%
sb.boxplot(df['Height'])
# Out:
# <Axes: ylabel='Height'>

# %%
upplimit = df['Height'].quantile(0.99)
print(upplimit)
# Out:
# 74.7857900583366

# %%
lowlimit = df['Height'].quantile(0.01)
print(lowlimit)
# Out:
# 58.13441158671655

# %%
newdf = df[(df['Height'] <= 74.78)  & (df['Height'] >= 58.13)]

# %%
newdf.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
newdf.shape                      #Trimming done
# Out:
# (9799, 3)

# %%
newdf['Height'].describe()
# Out:
# count    9799.000000
# mean       66.363507
# std         3.644267
# min        58.134496
# 25%        63.577147
# 50%        66.317899
# 75%        69.119859
# max        74.767447
# Name: Height, dtype: float64

# %%
sb.displot(df['Height'])

# %%
sb.boxplot(newdf['Height'])
# Out:
# <Axes: ylabel='Height'>

# %%
# Capping

# %%
df['Height']= np.where(df['Height'] >= upplimit,upplimit,np.where(df['Height'] <= lowlimit,lowlimit,df['Height']))

# %%
df.shape
# Out:
# (10000, 3)

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.366281
# std          3.795717
# min         58.134412
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         74.785790
# Name: Height, dtype: float64

# %%
sb.histplot(df['Height'])
# Out:
# <Axes: xlabel='Height', ylabel='Count'>

# %%
sb.boxplot(df['Height'])
# Out:
# <Axes: ylabel='Height'>
