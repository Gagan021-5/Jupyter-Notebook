# %%
import matplotlib.pyplot as plt
import matplotlib.image as mimg

# %%
myimg =mimg.imread('sampleimg.jpg')

# %%
plt.imshow(myimg)
plt.show()

# %%
import cv2

# %%
imagecv = cv2.imread('sampleimg.jpg',cv2.COLOR_BGR2RGB) 
plt.imshow(imagecv,aspect=1)

# %%
img1 = mimg.imread('captainprice.jpg')
img2 = mimg.imread('sample2.jpg')
img3 = mimg.imread('watchdogs.jpg')

# %%
plt.figure()
plt.style.use('dark_background')
plt.subplot(2,2,1)

plt.imshow(img1)

plt.figure()
plt.subplot(2,2,2)
plt.imshow(img2)

plt.figure()
plt.subplot(2,2,3)
plt.imshow(img3)
plt.show()

# %%
print(img1)
# Out:
# [[[147 144 139]
#   [147 144 139]
#   [147 144 139]
#   ...
#   [ 80  75  71]
#   [ 82  77  73]
#   [ 84  79  75]]
#
#  [[147 144 139]
#   [146 143 138]
#   [146 143 138]
#   ...
#   [ 83  78  74]
#   [ 85  80  76]
#   [ 86  81  77]]
#
#  [[146 143 138]
#   [145 142 137]
#   [144 141 136]
#   ...
#   [ 84  79  75]
#   [ 87  82  78]
#   [ 88  83  79]]
#
#  ...
#
#  [[ 16  12   9]
#   [ 16  12   9]
#   [ 16  12   9]
#   ...
#   [ 11  10   8]
#   [ 11  10   8]
#   [ 11  10   8]]
#
#  [[ 16  12   9]
#   [ 16  12   9]
#   [ 16  12   9]
#   ...
#   [ 11  10   8]
#   [ 11  10   8]
#   [ 11  10   8]]
#
#  [[ 16  12   9]
#   [ 16  12   9]
#   [ 16  12   9]
#   ...
#   [ 11  10   8]
#   [ 11  10   8]
#   [ 11  10   8]]]
