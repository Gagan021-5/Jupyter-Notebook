# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np

# %%
taxidf = sb.load_dataset('taxis')
taxidf.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %% [markdown]
# #### Scatter Plotting fxn

# %%
sb.scatterplot(x='fare',y='distance',data=taxidf,hue='tip')
plt.title("Fare vs Distance for Taxis data")
# Out:
# Text(0.5, 1.0, 'Fare vs Distance for Taxis data')

# %%
sb.scatterplot(x='fare',y='distance',data=taxidf,hue='tip',style='dropoff_zone',legend=False,palette='inferno',alpha=0.3)
sb.lineplot(x='fare',y='distance',data=taxidf,palette='brown')
# Out:
# C:\Users\Gagan\AppData\Local\Temp\ipykernel_12360\1955234558.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sb.lineplot(x='fare',y='distance',data=taxidf,palette='brown')
# <Axes: xlabel='fare', ylabel='distance'>

# %% [markdown]
# ## BarPlots (Bargraph)

# %%
sb.barplot(x='fare',y='distance',data=taxidf.head(),hue='passengers')
# Out:
# <Axes: xlabel='fare', ylabel='distance'>

# %%
#orient
sb.barplot(x='fare',y='distance',data=taxidf.head(),hue='passengers',
           orient='y')
# Out:
# <Axes: xlabel='fare', ylabel='distance'>

# %%
##Estimator
sb.barplot(x='fare',y='distance',data=taxidf.head(),hue='passengers',estimator=np.mean)
# Out:
# <Axes: xlabel='fare', ylabel='distance'>

# %%
#confidence interval
sb.barplot(x='fare',y='distance',data=taxidf.head(),hue='passengers',ci=100)
# Out:
# C:\Users\Gagan\AppData\Local\Temp\ipykernel_12360\2959047282.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 100)` for the same effect.
#
#   sb.barplot(x='fare',y='distance',data=taxidf.head(),hue='passengers',ci=100)
# <Axes: xlabel='fare', ylabel='distance'>
